# %% [markdown]
# <style>
# .titulo {
#   text-align: center;
# }
# .titulo h1 {
#   color: #fca311;
#   font-weight: 700;
#   font-size: 50px;
#   margin: 0;
#   padding: 0;
#   display: inline-block;
#   position: relative;
# }
# .titulo h1::after {
#   content: "";
#   display: block;
#   width: 100%;
#   height: 5px;
#   background-color: #4361ee;
#   position: absolute;
#   bottom: -10px;
#   left: 0%;
# }
# </style>
#
# <style>
# .description {
#     color: #4361ee;
#     font-weight:300;
#     font-size: 30px;
#     text-align:center;
#     justify-content: center;
#     padding: 10px;
#     margin: 0;
# }
# </style>
#
# <div class="titulo">
#   <h1>MindScope</h1>
#   </style>
#   <p class="description">LaborMarketTrends</p>
# </div>

# %% [markdown]
# ##### ***IMPORTAMOS LAS LIBRERÍAS***

# %%
# librerías para trabajar los Datasets.
import pandas as pd
import numpy as np

# Librerías para realizar gráficos.
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##### ***CARGAMOS LA BASE DE DATOS***

# %%
df_gd = pd.read_csv("./datasets/glassdoor.csv")
df_gd_benefitscomments = pd.read_csv("./datasets/glassdoor_benefits_comments.csv")
df_gd_benefitshighlights = pd.read_csv("./datasets/glassdoor_benefits_highlights.csv")
df_gd_breadcrumbs = pd.read_csv("./datasets/glassdoor_breadCrumbs.csv")
df_gd_overviewcompetitors = pd.read_csv("./datasets/glassdoor_overview_competitors.csv")
df_gd_photos = pd.read_csv("./datasets/glassdoor_photos.csv")
df_gd_review = pd.read_csv("./datasets/glassdoor_reviews.csv")
df_gd_reviewresponses = pd.read_csv("./datasets/glassdoor_reviews_val_reviewResponses.csv")
df_gd_salaries = pd.read_csv("./datasets/glassdoor_salary_salaries.csv")
df_gd_wwfu = pd.read_csv("./datasets/glassdoor_wwfu.csv")
df_gd_wwfucaptions = pd.read_csv("./datasets/glassdoor_wwfu_val_captions.csv")
df_gd_wwfuphotos = pd.read_csv("./datasets/glassdoor_wwfu_val_photos.csv")
df_gd_wwfuvideos = pd.read_csv("./datasets/glassdoor_wwfu_val_videos.csv")
df_countrynames = pd.read_csv("./datasets/country_names_2_digit_codes.csv")
df_currencyexchange =  pd.read_csv("./datasets/currency_exchange.csv")

# %% [markdown]
# #### ***VISUALIZAMOS LOS DATASETS***

# %%
# Establecemos esta linea para poder llegar a visualizar las 163 columnas...
pd.set_option('display.max_columns', None)

print("Tiene:", df_gd.shape[1], "columnas y", df_gd.shape[0], "filas")
df_gd.head(5)
# Out:
# Tiene: 163 columnas y 165290 filas
#    benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 0                            0.0             2801.0               2801.0
# 1                            4.0             2802.0               2802.0
# 2                            0.0             2803.0               2803.0
# 3                            0.0             2804.0               2804.0
# 4                            0.0             2805.0               2805.0
#
#    benefits.numRatings benefits.employerSummary  breadCrumbs  \
# 0                    0                      NaN         2801
# 1                    3                      NaN         2802
# 2                    0                      NaN         2803
# 3                    0                      NaN         2804
# 4                    0                      NaN         2805
#
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName  \
# ...

# %%
df_gd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Columns: 163 entries, benefits.benefitRatingDecimal to wwfu
# dtypes: bool(11), float64(35), int64(23), object(94)
# memory usage: 193.4+ MB

# %%
print("Tiene:", df_gd_benefitscomments.shape[1], "columnas y", df_gd_benefitscomments.shape[0], "filas")
df_gd_benefitscomments.head(5)
# Out:
# Tiene: 9 columnas y 271436 filas
#     id  index benefits.comments.val.city benefits.comments.val.comment  \
# 0  401    NaN                        NaN                           NaN
# 1  402    NaN                        NaN                           NaN
# 2  403    NaN                        NaN                           NaN
# 3  404    NaN                        NaN                           NaN
# 4  405    NaN                        NaN                           NaN
#
#   benefits.comments.val.createDate benefits.comments.val.currentJob  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   benefits.comments.val.jobTitle  benefits.comments.val.rating  \
# ...

# %%
df_gd_benefitscomments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271436 entries, 0 to 271435
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   id                                271436 non-null  int64
#  1   index                             169263 non-null  float64
#  2   benefits.comments.val.city        169263 non-null  object
#  3   benefits.comments.val.comment     169263 non-null  object
#  4   benefits.comments.val.createDate  169263 non-null  object
#  5   benefits.comments.val.currentJob  169263 non-null  object
#  6   benefits.comments.val.jobTitle    69296 non-null   object
#  7   benefits.comments.val.rating      169263 non-null  float64
#  8   benefits.comments.val.state       169263 non-null  object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 18.6+ MB

# %%
print("Tiene:", df_gd_benefitshighlights.shape[1], "columnas y", df_gd_benefitshighlights.shape[0], "filas")
df_gd_benefitshighlights.head(5)
# Out:
# Tiene: 6 columnas y 212155 filas
#       id            benefits.highlights.val.highlightPhrase  \
# 0  44001             good flexibility for working from home
# 1  44001  I’ve not really had any time off for the last ...
# 2  44001  Very flexible if you don't work overtime and y...
# 3  44002                                                NaN
# 4  44003                                                NaN
#
#   benefits.highlights.val.icon benefits.highlights.val.name  index  \
# 0                          wfh               Work From Home    0.0
# 1                     sickDays                     Sick Pay    1.0
# 2                flexWorkSched             Flexible Working    2.0
# 3                          NaN                          NaN    NaN
# 4                          NaN                          NaN    NaN
#
#    benefits.highlights.val.commentCount
# 0                                  17.0
# 1                                  14.0
# 2                                   7.0
# ...

# %%
df_gd_benefitshighlights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212155 entries, 0 to 212154
# Data columns (total 6 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   id                                       212155 non-null  int64
#  1   benefits.highlights.val.highlightPhrase  79900 non-null   object
#  2   benefits.highlights.val.icon             79900 non-null   object
#  3   benefits.highlights.val.name             79900 non-null   object
#  4   index                                    79900 non-null   float64
#  5   benefits.highlights.val.commentCount     79900 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.7+ MB

# %%
print("Tiene:", df_gd_breadcrumbs.shape[1], "columnas y", df_gd_breadcrumbs.shape[0], "filas")
df_gd_breadcrumbs.head(5)
# Out:
# Tiene: 4 columnas y 165290 filas
#       id  index breadCrumbs.val.name breadCrumbs.val.url
# 0  40801      0                 JOBS      /Job/index.htm
# 1  40802      0                 JOBS      /Job/index.htm
# 2  40803      0                 JOBS      /Job/index.htm
# 3  40804      0                 JOBS      /Job/index.htm
# 4  40805      0                 JOBS      /Job/index.htm

# %%
df_gd_breadcrumbs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Data columns (total 4 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    165290 non-null  int64
#  1   index                 165290 non-null  int64
#  2   breadCrumbs.val.name  165290 non-null  object
#  3   breadCrumbs.val.url   165290 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 5.0+ MB

# %%
print("Tiene:", df_gd_overviewcompetitors.shape[1], "columnas y", df_gd_overviewcompetitors.shape[0], "filas")
df_gd_overviewcompetitors.head(5)
# Out:
# Tiene: 3 columnas y 133336 filas
#       id  index overview.competitors.val
# 0  12526      0                    Apple
# 1  12526      1                Microsoft
# 2  12527      0              Finnovative
# 3  12527      1                  Temenos
# 4  12528      0                   Pfizer

# %%
df_gd_overviewcompetitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133336 entries, 0 to 133335
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        133336 non-null  int64
#  1   index                     133336 non-null  int64
#  2   overview.competitors.val  133336 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 3.1+ MB

# %%
print("Tiene:", df_gd_photos.shape[1], "columnas y", df_gd_photos.shape[0], "filas")
df_gd_photos.head(5)
# Out:
# Tiene: 8 columnas y 636159 filas
#       id  index       photos.val.caption  photos.val.photoId  \
# 0  26411      0                Mango day            10772510
# 1  26411      1  We REALLY like cupcakes            17246228
# 2  26411      2              Heli-skiing            17223544
# 3  26411      3   Rocking out in Karachi            17223536
# 4  26411      4             New offices!            17223528
#
#    photos.val.photoId2x                          photos.val.photoLink  \
# 0              10772511  /Photos/Afiniti-Office-Photos-IMG1912051.htm
# 1              17246229  /Photos/Afiniti-Office-Photos-IMG3404357.htm
# 2              17223545  /Photos/Afiniti-Office-Photos-IMG3399151.htm
# 3              17223537  /Photos/Afiniti-Office-Photos-IMG3399150.htm
# 4              17223529  /Photos/Afiniti-Office-Photos-IMG3399149.htm
#
#                                  photos.val.photoUrl  \
# 0  https://media.glassdoor.com/lst/1436090/afinit...
# ...

# %%
df_gd_photos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636159 entries, 0 to 636158
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     636159 non-null  int64
#  1   index                  636159 non-null  int64
#  2   photos.val.caption     635438 non-null  object
#  3   photos.val.photoId     636159 non-null  int64
#  4   photos.val.photoId2x   636159 non-null  int64
#  5   photos.val.photoLink   636159 non-null  object
#  6   photos.val.photoUrl    636159 non-null  object
#  7   photos.val.photoUrl2x  636159 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 38.8+ MB

# %%
print("Tiene:", df_gd_review.shape[1], "columnas y", df_gd_review.shape[0], "filas")
df_gd_review.head(5)
# Out:
# Tiene: 28 columnas y 422180 filas
#       id  index                                   reviews.val.cons  \
# 0  44001    0.0               Still not big enough in market place
# 1  44002    NaN                                                NaN
# 2  44003    NaN                                                NaN
# 3  44004    0.0             Nothing important on my point of view.
# 4  44004    1.0  Alot of friends working together which isn't v...
#
#   reviews.val.date reviews.val.featured  reviews.val.helpfulCount  \
# 0     Oct 20, 2010                False                       0.0
# 1              NaN                  NaN                       NaN
# 2              NaN                  NaN                       NaN
# 3      4 weeks ago                False                       0.0
# 4     May 29, 2019                False                       0.0
#
#    reviews.val.id                                   reviews.val.pros  \
# ...

# %%
df_gd_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422180 entries, 0 to 422179
# Data columns (total 28 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   id                                             422180 non-null  int64
#  1   index                                          343221 non-null  float64
#  2   reviews.val.cons                               343214 non-null  object
#  3   reviews.val.date                               343221 non-null  object
#  4   reviews.val.featured                           343221 non-null  object
#  5   reviews.val.helpfulCount                       343221 non-null  float64
#  6   reviews.val.id                                 343221 non-null  float64
#  7   reviews.val.pros                               343221 non-null  object
#  8   reviews.val.publishedOn                        343221 non-null  object
# ...

# %%
print("Tiene:", df_gd_reviewresponses.shape[1], "columnas y", df_gd_reviewresponses.shape[0], "filas")
df_gd_reviewresponses.head(5)
# Out:
# Tiene: 10 columnas y 25267 filas
#      id  index reviews.val.reviewResponses.val.createDate  \
# 0  6762      0                        2018-05-01T03:54:11
# 1  6763      0                        2018-07-17T06:15:22
# 2  6764      0                        2019-01-04T11:48:06
# 3  6765      0                        2018-07-25T12:07:51
# 4  6766      0                        2019-01-16T02:02:05
#
#    reviews.val.reviewResponses.val.helpfulCount  \
# 0                                             0
# 1                                             0
# 2                                             0
# 3                                             0
# 4                                             0
#
#    reviews.val.reviewResponses.val.jobTitle  \
# 0                                       NaN
# 1  Culture &amp; Engagement Program Manager
# 2  Culture &amp; Engagement Program Manager
# 3  Culture &amp; Engagement Program Manager
# 4          Marketing Communications Manager
#
# ...

# %%
df_gd_reviewresponses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25267 entries, 0 to 25266
# Data columns (total 10 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   id                                                  25267 non-null  int64
#  1   index                                               25267 non-null  int64
#  2   reviews.val.reviewResponses.val.createDate          25267 non-null  object
#  3   reviews.val.reviewResponses.val.helpfulCount        25267 non-null  int64
#  4   reviews.val.reviewResponses.val.jobTitle            22585 non-null  object
#  5   reviews.val.reviewResponses.val.notHelpfulCount     25267 non-null  int64
#  6   reviews.val.reviewResponses.val.responseText        25267 non-null  object
#  7   reviews.val.reviewResponses.val.responseTextLength  25267 non-null  int64
# ...

# %%
print("Tiene:", df_gd_salaries.shape[1], "columnas y", df_gd_salaries.shape[0], "filas")
df_gd_salaries.head(5)
# Out:
# Tiene: 9 columnas y 408763 filas
#    id  index  salary.salaries.val.basePayCount salary.salaries.val.jobTitle  \
# 0   1    NaN                               NaN                          NaN
# 1   2    0.0                               9.0          Advanced Consultant
# 2   2    1.0                               7.0                   Consultant
# 3   2    2.0                               7.0            Software Engineer
# 4   2    3.0                               4.0              Project Manager
#
#   salary.salaries.val.payPeriod  \
# 0                           NaN
# 1                        ANNUAL
# 2                        ANNUAL
# 3                        ANNUAL
# 4                        ANNUAL
#
#    salary.salaries.val.salaryPercentileMap.payPercentile10  \
# 0                                                NaN
# 1                                           32257.68
# 2                                           28855.30
# ...

# %%
df_gd_salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408763 entries, 0 to 408762
# Data columns (total 9 columns):
#  #   Column                                                   Non-Null Count   Dtype
# ---  ------                                                   --------------   -----
#  0   id                                                       408763 non-null  int64
#  1   index                                                    338391 non-null  float64
#  2   salary.salaries.val.basePayCount                         338391 non-null  float64
#  3   salary.salaries.val.jobTitle                             338364 non-null  object
#  4   salary.salaries.val.payPeriod                            338391 non-null  object
#  5   salary.salaries.val.salaryPercentileMap.payPercentile10  338357 non-null  float64
#  6   salary.salaries.val.salaryPercentileMap.payPercentile90  338357 non-null  float64
#  7   salary.salaries.val.salaryPercentileMap.payPercentile50  189128 non-null  float64
# ...

# %%
print("Tiene:", df_gd_wwfu.shape[1], "columnas y", df_gd_wwfu.shape[0], "filas")
df_gd_wwfu.head(5)
# Out:
# Tiene: 9 columnas y 86115 filas
#     id  index                                      wwfu.val.body  wwfu.val.id  \
# 0  449      0  <p><img class="lazy" style="display: block; ma...       133403
# 1  449      1  <p><iframe style="display: block; margin-left:...       133404
# 2  449      2  <p><img class="lazy" style="display: block; ma...       133405
# 3  449      3  <p><iframe style="display: block; margin-left:...       133406
# 4  449      4  <p style="text-align: center;"><iframe src="ht...       133407
#
#   wwfu.val.title wwfu.val.type  wwfu.val.videos  wwfu.val.photos  \
# 0       About Us        CUSTOM              NaN              NaN
# 1        Careers        CUSTOM              NaN              NaN
# 2       Benefits        CUSTOM              NaN              NaN
# 3    Why Micron?        CUSTOM              NaN              NaN
# 4      Diversity        CUSTOM              NaN              NaN
#
#    wwfu.val.captions
# 0                NaN
# 1                NaN
# ...

# %%
df_gd_wwfu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86115 entries, 0 to 86114
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 86115 non-null  int64
#  1   index              86115 non-null  int64
#  2   wwfu.val.body      86115 non-null  object
#  3   wwfu.val.id        86115 non-null  int64
#  4   wwfu.val.title     86115 non-null  object
#  5   wwfu.val.type      85815 non-null  object
#  6   wwfu.val.videos    17621 non-null  float64
#  7   wwfu.val.photos    9496 non-null   float64
#  8   wwfu.val.captions  5781 non-null   float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 5.9+ MB

# %%
print("Tiene:", df_gd_wwfucaptions.shape[1], "columnas y", df_gd_wwfucaptions.shape[0], "filas")
df_gd_wwfucaptions.head(5)
# Out:
# Tiene: 3 columnas y 7544 filas
#      id  index                              wwfu.val.captions.val
# 0  1407      0                              Our interview process
# 1  1408      0           Andrew Watson | Head of Machine Learning
# 2  1408      1           Connected studio | Singapore Tech Centre
# 3  1409      0           Melloney Luckhurst- UI Designer at Dyson
# 4  1409      1  Dyson UK campus, D9 (left) Lightning Cafe (right)

# %%
df_gd_wwfucaptions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7544 entries, 0 to 7543
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     7544 non-null   int64
#  1   index                  7544 non-null   int64
#  2   wwfu.val.captions.val  7544 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 176.9+ KB

# %%
print("Tiene:", df_gd_wwfuphotos.shape[1], "columnas y", df_gd_wwfuphotos.shape[0], "filas")
df_gd_wwfuphotos.head(5)
# Out:
# Tiene: 3 columnas y 11436 filas
#      id  index                                wwfu.val.photos.val
# 0  2370      0  https://media.glassdoor.com/template/l/40772/f...
# 1  2371      0  https://media.glassdoor.com/template/l/40772/f...
# 2  2372      0  https://media.glassdoor.com/template/l/1162798...
# 3  2373      0  https://media.glassdoor.com/template/l/1162798...
# 4  2374      0  https://media.glassdoor.com/template/l/7774/ta...

# %%
df_gd_wwfuphotos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11436 entries, 0 to 11435
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   11436 non-null  int64
#  1   index                11436 non-null  int64
#  2   wwfu.val.photos.val  11436 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 268.2+ KB

# %%
print("Tiene:", df_gd_wwfuvideos.shape[1], "columnas y", df_gd_wwfuvideos.shape[0], "filas")
df_gd_wwfuvideos.head(5)
# Out:
# Tiene: 3 columnas y 17687 filas
#      id  index                                wwfu.val.videos.val
# 0  4327      0  <iframe width="560" height="315" src="https://...
# 1  4328      0  <iframe width="560" height="315" src="https://...
# 2  4329      0  <iframe width="560" height="315" src="https://...
# 3  4330      0  <iframe width="560" height="315" src="https://...
# 4  4331      0  <iframe width="560" height="315" src="https://...

# %%
df_gd_wwfuvideos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17687 entries, 0 to 17686
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   17687 non-null  int64
#  1   index                17687 non-null  int64
#  2   wwfu.val.videos.val  17687 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 414.7+ KB

# %%
print("Tiene:", df_countrynames.shape[1], "columnas y", df_countrynames.shape[0], "filas")
df_countrynames.head(5)
# Out:
# Tiene: 2 columnas y 249 filas
#              Name Code
# 0     Afghanistan   AF
# 1  Ã…land Islands   AX
# 2         Albania   AL
# 3         Algeria   DZ
# 4  American Samoa   AS

# %%
df_countrynames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    249 non-null    object
#  1   Code    248 non-null    object
# dtypes: object(2)
# memory usage: 4.0+ KB

# %%
print("Tiene:", df_currencyexchange.shape[1], "columnas y", df_currencyexchange.shape[0], "filas")
df_currencyexchange.head(5)
# Out:
# Tiene: 5 columnas y 268 filas
#   Code                     Country                       Currency  Number  \
# 0  AED  United Arab Emirates (The)                     UAE Dirham   784.0
# 1  AFN                 Afghanistan                        Afghani   971.0
# 2  ALL                     Albania                            Lek     8.0
# 3  AMD                     Armenia                  Armenian Dram    51.0
# 4  ANG                     Curaçao  Netherlands Antillean Guilder   532.0
#
#    ExchangeRate
# 0      3.672779
# 1     78.250197
# 2    111.702860
# 3    477.169811
# 4      1.734311

# %%
df_currencyexchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Code          265 non-null    object
#  1   Country       268 non-null    object
#  2   Currency      268 non-null    object
#  3   Number        265 non-null    float64
#  4   ExchangeRate  253 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 10.6+ KB
