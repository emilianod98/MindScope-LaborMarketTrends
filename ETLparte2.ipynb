# %%
# Importing all the neccessary libraries
import pandas as pd # To load files and perform tasks
import numpy as np # linear algebra
import seaborn as sns  # data visualizations
import matplotlib.pyplot as plt # data visualizations

# %%
#import plotly  #  interactive plotting library

# %%
df_cn= pd.read_csv("datasets/country_names_2_digit_codes.csv")
df_ce= pd.read_csv("datasets/currency_exchange.csv")
df_cex= pd.read_csv("datasets/glassdoor_benefits_comments.csv")
df_cnh= pd.read_csv("datasets/glassdoor_benefits_highlights.csv")
df_cnc= pd.read_csv("datasets/glassdoor_breadCrumbs.csv")
df_goc= pd.read_csv("datasets/glassdoor_overview_competitors.csv")
df_f= pd.read_csv("datasets/glassdoor_photos.csv")
df_grv= pd.read_csv("datasets/glassdoor_reviews_val_reviewResponses.csv")
df_gr= pd.read_csv("datasets/glassdoor_reviews.csv")
df_gss= pd.read_csv("datasets/glassdoor_salary_salaries.csv")
df_gwv= pd.read_csv("datasets/glassdoor_wwfu_val_captions.csv")
df_gwvp= pd.read_csv("datasets/glassdoor_wwfu_val_photos.csv")
df_gwvv= pd.read_csv("datasets/glassdoor_wwfu_val_videos.csv")
df_gww= pd.read_csv("datasets/glassdoor_wwfu.csv")
df_g= pd.read_csv("datasets/glassdoor.csv")

# %%
df_cn
# Out:
#                   Name Code
# 0          Afghanistan   AF
# 1       Ã…land Islands   AX
# 2              Albania   AL
# 3              Algeria   DZ
# 4       American Samoa   AS
# ..                 ...  ...
# 244  Wallis and Futuna   WF
# 245     Western Sahara   EH
# 246              Yemen   YE
# 247             Zambia   ZM
# 248           Zimbabwe   ZW
#
# [249 rows x 2 columns]

# %%
df_cn.head(1)
# Out:
#           Name Code
# 0  Afghanistan   AF

# %%
df_ce.head(1)
# Out:
#   Code                     Country    Currency  Number  ExchangeRate
# 0  AED  United Arab Emirates (The)  UAE Dirham   784.0      3.672779

# %%
df_cex.head(1)
# Out:
#     id  index benefits.comments.val.city benefits.comments.val.comment  \
# 0  401    NaN                        NaN                           NaN
#
#   benefits.comments.val.createDate benefits.comments.val.currentJob  \
# 0                              NaN                              NaN
#
#   benefits.comments.val.jobTitle  benefits.comments.val.rating  \
# 0                            NaN                           NaN
#
#   benefits.comments.val.state
# 0                         NaN

# %%
df_cnh.head(1)
# Out:
#       id benefits.highlights.val.highlightPhrase benefits.highlights.val.icon  \
# 0  44001  good flexibility for working from home                          wfh
#
#   benefits.highlights.val.name  index  benefits.highlights.val.commentCount
# 0               Work From Home    0.0                                  17.0

# %%
df_cnc.head(1)
# Out:
#       id  index breadCrumbs.val.name breadCrumbs.val.url
# 0  40801      0                 JOBS      /Job/index.htm

# %%
df_goc.head(1)
# Out:
#       id  index overview.competitors.val
# 0  12526      0                    Apple

# %%
df_f.head(1)
# Out:
#       id  index photos.val.caption  photos.val.photoId  photos.val.photoId2x  \
# 0  26411      0          Mango day            10772510              10772511
#
#                            photos.val.photoLink  \
# 0  /Photos/Afiniti-Office-Photos-IMG1912051.htm
#
#                                  photos.val.photoUrl  \
# 0  https://media.glassdoor.com/lst/1436090/afinit...
#
#                                photos.val.photoUrl2x
# 0  https://media.glassdoor.com/lst2x/1436090/afin...

# %%
df_grv.head(1)
# Out:
#      id  index reviews.val.reviewResponses.val.createDate  \
# 0  6762      0                        2018-05-01T03:54:11
#
#    reviews.val.reviewResponses.val.helpfulCount  \
# 0                                             0
#
#   reviews.val.reviewResponses.val.jobTitle  \
# 0                                      NaN
#
#    reviews.val.reviewResponses.val.notHelpfulCount  \
# 0                                                0
#
#   reviews.val.reviewResponses.val.responseText  \
# 0                   Thank you for your review.
#
#    reviews.val.reviewResponses.val.responseTextLength  \
# 0                                                 26
#
#    reviews.val.reviewResponses.val.totalHelpfulCount  \
# 0                                                  0
#
#   reviews.val.reviewResponses.val.updateDate
# 0                        2018-05-02T00:23:37

# %%
df_grv.head(1)
# Out:
#      id  index reviews.val.reviewResponses.val.createDate  \
# 0  6762      0                        2018-05-01T03:54:11
#
#    reviews.val.reviewResponses.val.helpfulCount  \
# 0                                             0
#
#   reviews.val.reviewResponses.val.jobTitle  \
# 0                                      NaN
#
#    reviews.val.reviewResponses.val.notHelpfulCount  \
# 0                                                0
#
#   reviews.val.reviewResponses.val.responseText  \
# 0                   Thank you for your review.
#
#    reviews.val.reviewResponses.val.responseTextLength  \
# 0                                                 26
#
#    reviews.val.reviewResponses.val.totalHelpfulCount  \
# 0                                                  0
#
#   reviews.val.reviewResponses.val.updateDate
# 0                        2018-05-02T00:23:37

# %%
df_gr.head(1)
# Out:
#       id  index                      reviews.val.cons reviews.val.date  \
# 0  44001    0.0  Still not big enough in market place     Oct 20, 2010
#
#   reviews.val.featured  reviews.val.helpfulCount  reviews.val.id  \
# 0                False                       0.0        689142.0
#
#                                     reviews.val.pros reviews.val.publishedOn  \
# 0  Great brand , Good leadership , Clear business...            Oct 20, 2010
#
#   reviews.val.publisher  ...  reviews.val.reviewerJobTitle  \
# 0              Director  ...                      Director
#
#    reviews.val.reviewerLocation  reviews.val.reviewerStatus  \
# 0                 Tokyo (Japan)             Former Employee
#
#    reviews.val.summaryPoints.ceoApproval  reviews.val.summaryPoints.outlook  \
# 0                                    1.0                                0.0
#
#    reviews.val.summaryPoints.recommend  \
# 0                                  1.0
#
# ...

# %%
df_gss.head(1)
# Out:
#    id  index  salary.salaries.val.basePayCount salary.salaries.val.jobTitle  \
# 0   1    NaN                               NaN                          NaN
#
#   salary.salaries.val.payPeriod  \
# 0                           NaN
#
#    salary.salaries.val.salaryPercentileMap.payPercentile10  \
# 0                                                NaN
#
#    salary.salaries.val.salaryPercentileMap.payPercentile90  \
# 0                                                NaN
#
#    salary.salaries.val.salaryPercentileMap.payPercentile50  \
# 0                                                NaN
#
#   salary.salaries.val.salaryType
# 0                            NaN

# %%
df_gwv.head(1)
# Out:
#      id  index  wwfu.val.captions.val
# 0  1407      0  Our interview process

# %%
df_gwvp.head(1)
# Out:
#      id  index                                wwfu.val.photos.val
# 0  2370      0  https://media.glassdoor.com/template/l/40772/f...

# %%
df_gwvv.head(1)
# Out:
#      id  index                                wwfu.val.videos.val
# 0  4327      0  <iframe width="560" height="315" src="https://...

# %%
df_gww.head(1)
# Out:
#     id  index                                      wwfu.val.body  wwfu.val.id  \
# 0  449      0  <p><img class="lazy" style="display: block; ma...       133403
#
#   wwfu.val.title wwfu.val.type  wwfu.val.videos  wwfu.val.photos  \
# 0       About Us        CUSTOM              NaN              NaN
#
#    wwfu.val.captions
# 0                NaN

# %%
df_g.head(1)
# Out:
#    benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 0                            0.0             2801.0               2801.0
#
#    benefits.numRatings benefits.employerSummary  breadCrumbs  \
# 0                    0                      NaN         2801
#
#    gaTrackerData.category  gaTrackerData.empId gaTrackerData.empName  \
# 0                      -1              2183810           Modus Group
#
#   gaTrackerData.empSize  ...  salary.currency.displayName salary.currency.id  \
# 0              501-1000  ...                          NaN                NaN
#
#    salary.currency.name  salary.currency.negativeTemplate  \
# 0                   NaN                               NaN
#
#    salary.currency.new salary.currency.positiveTemplate  \
# 0                  NaN                              NaN
#
#   salary.currency.symbol  salary.lastSalaryDate salary.salaries wwfu
# 0                    NaN                    NaN          2483.0  NaN
#
# ...

# %%
# Dividimos el DataFrame en cuatro DataFrames
df_gs = np.array_split(df_g, 8, axis=1)

# %%
# Asigna cada DataFrame a una variable
df_g1 = df_gs[0]
df_g2 = df_gs[1]
df_g3 = df_gs[2]
df_g4 = df_gs[3]
df_g5 = df_gs[4]
df_g6 = df_gs[5]
df_g7 = df_gs[6]
df_g8 = df_gs[7]

# %%
# Selecciono ciertas columnas 
df_selec1 = df_g1[["benefits.numRatings", "gaTrackerData.empId", "gaTrackerData.empName","gaTrackerData.empSize", "gaTrackerData.industry","gaTrackerData.industryId", "gaTrackerData.jobTitle", "gaTrackerData.location","gaTrackerData.locationId"]]
df_selec2 = df_g2[["gaTrackerData.sectorId", "header.advertiserType"]]
df_selec3 = df_g3[["header.jobTitle","header.locId", "header.location", "header.rating","header.normalizedJobTitle"]]
df_selec4 = df_g4[["header.payHigh","header.payLow", "header.payMed","header.payPeriod", "header.salaryHigh","job.description","job.jobTitleId"]]
df_selec5 = df_g5[["map.country","map.employerName", "map.lat","map.lng", "map.location","overview.hq","overview.industry","overview.revenue","overview.sectorId","overview.size"]]
df_selec6 = df_g6[["rating.ceo.name"]]
df_selec7 = df_g7[["salary.country.continent.id","salary.country.countryFIPS", "salary.country.currency.currencyCode","salary.country.currency.displayName", "salary.country.currency.id","salary.country.currency.name","salary.country.currencyCode"]]
df_selec8 = df_g8[["salary.country.name","salary.country.population", "salary.country.shortName","salary.currency.currencyCode","salary.salaries","wwfu"]]

# %%
df_g8["wwfu"].unique()
# Out:
# array([nan, 310.0, 311.0, ..., 6613.0, 6614.0, 6615.0], dtype=object)

# %%
#df_g8

# %%
#df_g1
#df_g2
#df_g3
#df_g4
#df_g5
#df_g6
#df_g7
#df_g8

# %%
df_selec7
# Out:
#        salary.country.continent.id salary.country.countryFIPS  \
# 0                              NaN                        NaN
# 1                              4.0                         UK
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# ...                            ...                        ...
# 165285                         NaN                        NaN
# 165286                         4.0                         UK
# 165287                         NaN                        NaN
# 165288                         NaN                        NaN
# 165289                         NaN                        NaN
#
#        salary.country.currency.currencyCode  \
# 0                                       NaN
# 1                                       GBP
# 2                                       NaN
# ...

# %%
#df_selec4

# %%
#df_selec4.head()

# %%
#df_selec1.isnull().sum()
#df_selec2.isnull().sum()
#df_selec3.isnull().sum()
#df_selec4.isnull().sum()
#df_selec5.isnull().sum()
#df_selec6.isnull().sum()
#df_selec7.isnull().sum()
df_selec8.isnull().sum()
# Out:
# salary.country.name              88513
# salary.country.population        88513
# salary.country.shortName         88513
# salary.currency.currencyCode     88513
# salary.salaries                  18141
# wwfu                            146549
# dtype: int64

# %%
#df_selec1.duplicated().sum()
#df_selec2.duplicated().sum()
#df_selec3.duplicated().sum()
#df_selec4.duplicated().sum()
#df_selec5.duplicated().sum()
#df_selec6.duplicated().sum()
#df_selec7.duplicated().sum()
df_selec8.duplicated().sum()
# Out:
# 18140

# %%
#df_selec1.info()
#df_selec2.info()
#df_selec3.info()
#df_selec4.info()
#df_selec5.info()
#df_selec6.info()
#df_selec7.info()
df_selec8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   salary.country.name           76777 non-null   object
#  1   salary.country.population     76777 non-null   object
#  2   salary.country.shortName      76777 non-null   object
#  3   salary.currency.currencyCode  76777 non-null   object
#  4   salary.salaries               147149 non-null  object
#  5   wwfu                          18741 non-null   object
# dtypes: object(6)
# memory usage: 7.6+ MB

# %% [markdown]
# # __---------------------------------------------------------------------------__

# %% [markdown]
# # __Moneda__

# %%
'''
MONEDA: "header.payHigh","header.payLow", "header.payMed","header.payPeriod", "header.salaryHigh", 
"salary.country.continent.id","salary.country.countryFIPS", "salary.country.currency.currencyCode","salary.country.currency.displayName", "salary.country.currency.id",
"salary.country.currency.name","salary.country.currencyCode", "salary.country.name","salary.country.population", "salary.country.shortName","salary.currency.currencyCode",
"salary.salaries","wwfu'   '''
# Out:
# '\nMONEDA: "header.payHigh","header.payLow", "header.payMed","header.payPeriod", "header.salaryHigh", \n"salary.country.continent.id","salary.country.countryFIPS", "salary.country.currency.currencyCode","salary.country.currency.displayName", "salary.country.currency.id",\n"salary.country.currency.name","salary.country.currencyCode", "salary.country.name","salary.country.population", "salary.country.shortName","salary.currency.currencyCode",\n"salary.salaries","wwfu\'   '

# %%
#Select7

#df_selec7['salary.country.countryFIPS'].unique() #Solo tiene UK and Nan
#df_selec7["salary.country.continent.id"].unique() #nan y 4.0
#df_selec7["salary.country.currency.currencyCode"].unique() #Solo GBP y nan
#df_selec7["salary.country.currency.displayName"].unique() #United Kingdom Pound (GBP) y nan
#df_selec7["salary.country.currency.id"].unique() #2.0 y nan
#df_selec7["salary.country.currency.name"].unique()# United Kingdom pound
#df_selec7["salary.country.currencyCode"].unique()#GBP y nan


#Select8

#df_selec8["salary.country.name"].unique() #United Kingdom y nan
#df_selec8["salary.country.population"].unique() # nan y 60363602.0
#df_selec8["salary.country.shortName"].unique() # nan y UK
#df_selec8['salary.currency.currencyCode'].unique() # nan y GBP, USD, EUR, CHF, CAD

#Select4

#df_selec4["header.payPeriod"].unique() #nan, ANNUAL, HOURLY

#Select7

# df_selec7['salary.country.currency.currencyCode'].unique() #nan y GBP

# %%
#df_selec8["salary.currency.currencyCode"].sample(50)
#df_selec8[df_selec8["salary.currency.currencyCode"] == "USD"].sample(50)

#DATOS DE LA COLUMNA salary.currency.currency.Code

#(df_selec8["salary.currency.currencyCode"] == "USD").sum() #56 USD
#(df_selec8["salary.currency.currencyCode"] == "EUR").sum() # 61 EUR
#(df_selec8["salary.currency.currencyCode"] == "CHF").sum() # 6 CHF
#(df_selec8["salary.currency.currencyCode"] == "CAD").sum()  # 2 CAD
#(df_selec8["salary.currency.currencyCode"] == "GBP").sum() # 76652, eso sin contar lo que se tiene para complementar de los otros

# %%
print('header payHigh: ',df_selec4['header.payHigh'].unique(),'\nheader paylow: ',
df_selec4['header.payLow'].unique(),'\nheader paymed: ',
df_selec4['header.payMed'].unique(),'\nheader payPeriod: ',
df_selec4['header.payPeriod'].unique(),'\nheader salary high: ',
df_selec4['header.salaryHigh'].unique(),'\n',
)
print('\n','\n','\n','\n','-Nulos-')

print(df_selec4['header.payHigh'].isnull().sum(),
df_selec4['header.payLow'].isnull().sum(),
df_selec4['header.payMed'].isnull().sum(),
df_selec4['header.payPeriod'].isnull().sum(),
df_selec4['header.salaryHigh'].isnull().sum())
# Out:
# header payHigh:  [nan 182160.0 136276.0 ... 116887.0 100885.0 107219.0]
# header paylow:  [nan 132630.0 93444.0 ... 77999.0 66689.0 68090.0]
# header paymed:  [nan 159427.0 115139.0 ... 96171.0 82206.0 86238.0]
# header payPeriod:  [nan 'ANNUAL' 'HOURLY']
# header salary high:  [nan 182160.0 136276.0 ... 116887.0 100885.0 107219.0]
#
#
#
#
#
#  -Nulos-
# 161628 161628 161648 161653 161628

# %%
print('salary.country.continent.id: ',df_selec7['salary.country.continent.id'].unique(),'\nsalary.country.countryFIPS: ',
df_selec7['salary.country.countryFIPS'].unique(),'\nsalary.country.currency.currencyCode: ',
df_selec7['salary.country.currency.currencyCode'].unique(),'\nsalary.country.currency.displayName: ',
df_selec7['salary.country.currency.displayName'].unique(),'\nsalary.country.currency.id: ',
df_selec7['salary.country.currency.id'].unique(),'\nsalary.country.currency.name',
df_selec7['salary.country.currency.name'].unique(),'\nsalary.country.currencyCode: ',
df_selec7['salary.country.currencyCode'].unique(),'\n',
)
print('\n','\n','\n','\n','-Nulos-')

print(df_selec7['salary.country.continent.id'].isnull().sum(),
df_selec7['salary.country.countryFIPS'].isnull().sum(),
df_selec7['salary.country.currency.currencyCode'].isnull().sum(),
df_selec7['salary.country.currency.displayName'].isnull().sum(),
df_selec7['salary.country.currency.id'].isnull().sum(),
df_selec7['salary.country.currency.name'].isnull().sum(),
df_selec7['salary.country.currencyCode'].isnull().sum())
# Out:
# salary.country.continent.id:  [nan 4.0]
# salary.country.countryFIPS:  [nan 'UK']
# salary.country.currency.currencyCode:  [nan 'GBP']
# salary.country.currency.displayName:  [nan 'United Kingdom Pound (GBP)']
# salary.country.currency.id:  [nan 2.0]
# salary.country.currency.name [nan 'United Kingdom Pound']
# salary.country.currencyCode:  [nan 'GBP']
#
#
#
#
#
#  -Nulos-
# 88513 88513 88513 88513 88513 88513 88513

# %%
print('salary.country.name: ',df_selec8['salary.country.name'].unique(),'\nsalary.country.population: ',
df_selec8['salary.country.population'].unique(),'\nsalary.country.shortName: ',
df_selec8['salary.country.shortName'].unique(),'\nsalary.currency.currencyCode: ',
df_selec8['salary.currency.currencyCode'].unique(),'\nsalary.salaries: ',
df_selec8['salary.salaries'].unique(),'\nwwfu: ',
df_selec8['wwfu'].unique(),'\n',
)
print('\n','\n','\n','\n','-Nulos-')

print(df_selec8['salary.country.name'].isnull().sum(),
df_selec8['salary.country.population'].isnull().sum(),
df_selec8['salary.country.shortName'].isnull().sum(),
df_selec8['salary.currency.currencyCode'].isnull().sum(),
df_selec8['salary.salaries'].isnull().sum(),
df_selec8['wwfu'].isnull().sum())
# Out:
# salary.country.name:  [nan 'United Kingdom']
# salary.country.population:  [nan 60363602.0]
# salary.country.shortName:  [nan 'UK']
# salary.currency.currencyCode:  [nan 'GBP' 'USD' 'EUR' 'CHF' 'CAD']
# salary.salaries:  [2483.0 2484.0 2485.0 ... 52077.0 52078.0 52079.0]
# wwfu:  [nan 310.0 311.0 ... 6613.0 6614.0 6615.0]
#
#
#
#
#
#  -Nulos-
# 88513 88513 88513 88513 18141 146549

# %%
#Creacion de la columna valor promedio
#df_economy['avg_salary'] = df_selec4[["header.payHigh","header.payLow", "header.payMed"]].mean(axis=1)

# %%
#Metodo para meter datos de un df al otro en las partes nulas: df_economy = df1.combine_first(df2)

# %%
#Primera parte del dataset
df_p1 = df_selec4[["header.payHigh","header.payLow", "header.payMed", "header.salaryHigh", "header.payPeriod"]]
df_p2 = df_selec8[["salary.salaries"]]
df_p3 = df_selec7[["salary.country.currency.currencyCode"]]

df_use = pd.concat([df_p1, df_p2, df_p3], axis=1)

# %%
df_use
# Out:
#        header.payHigh header.payLow header.payMed header.salaryHigh  \
# 0                 NaN           NaN           NaN               NaN
# 1                 NaN           NaN           NaN               NaN
# 2                 NaN           NaN           NaN               NaN
# 3                 NaN           NaN           NaN               NaN
# 4                 NaN           NaN           NaN               NaN
# ...               ...           ...           ...               ...
# 165285            NaN           NaN           NaN               NaN
# 165286            NaN           NaN           NaN               NaN
# 165287            NaN           NaN           NaN               NaN
# 165288            NaN           NaN           NaN               NaN
# 165289            NaN           NaN           NaN               NaN
#
#        header.payPeriod salary.salaries salary.country.currency.currencyCode
# ...

# %%
df_use['header.salaryHigh'][df_use['header.salaryHigh'].notnull()].sample(5)
# Out:
# 76783     124644.0
# 71842      61727.0
# 53277     123301.0
# 108824     70477.0
# 121792     69130.0
# Name: header.salaryHigh, dtype: object

# %%
df_use
# Out:
#        header.payHigh header.payLow header.payMed header.salaryHigh  \
# 0                 NaN           NaN           NaN               NaN
# 1                 NaN           NaN           NaN               NaN
# 2                 NaN           NaN           NaN               NaN
# 3                 NaN           NaN           NaN               NaN
# 4                 NaN           NaN           NaN               NaN
# ...               ...           ...           ...               ...
# 165285            NaN           NaN           NaN               NaN
# 165286            NaN           NaN           NaN               NaN
# 165287            NaN           NaN           NaN               NaN
# 165288            NaN           NaN           NaN               NaN
# 165289            NaN           NaN           NaN               NaN
#
#        header.payPeriod salary.salaries salary.country.currency.currencyCode
# ...

# %% [markdown]
# ### __Se normalizaron los datos utilizando el promedio de los datos existentes en base al crecimiento del promedio de cada una de las columnas de valores relevantes__

# %%
means = df_use.mean(axis=0)
# Out:
# C:\Users\matia\AppData\Local\Temp\ipykernel_26316\3916128692.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = df_use.mean(axis=0)

# %%
df_use= df_use.fillna(value=means)

# %%
# Paso 5: Calcular porcentaje de crecimiento o decrecimiento de cada columna
# en relación a la columna de salarios

# Primero, convierte todas las columnas a numéricas
df_use = df_use.apply(pd.to_numeric, errors='coerce')

# Calcula la diferencia entre la columna de salarios y cada una de las otras columnas
differences = df_use.subtract(df_use["salary.salaries"], axis=0)

# Calcula el porcentaje de cambio dividiendo la diferencia por el valor de la columna de salarios y multiplicando por 100
percentages = differences.divide(df_use["salary.salaries"], axis=0) * 100

# Calcula la media de los porcentajes para cada columna, ignorando los valores NaN
percentage_means = percentages.mean(skipna=True)

# Asegúrate de que las columnas no numéricas (como las cadenas de caracteres) se mantengan como NaN
percentage_means = percentage_means.where(pd.notnull(percentage_means), None)

# %%
differences = df_use.subtract(df_use["salary.salaries"], axis=0)

# %%
percentages = differences.divide(df_use["header.salaryHigh"], axis=0) * 100

# %%
percentage_means = percentages.mean(axis=0)

# %%
for col in df_use.columns:
    if df_use[col].isnull().values.any():
        df_use[col] = df_use["salary.salaries"] * (1 + percentage_means[col]/100)

# %%
df_use
# Out:
#         header.payHigh  header.payLow  header.payMed  header.salaryHigh  \
# 0        115832.403605   77825.276898   95296.689182      115832.403605
# 1        115832.403605   77825.276898   95296.689182      115832.403605
# 2        115832.403605   77825.276898   95296.689182      115832.403605
# 3        115832.403605   77825.276898   95296.689182      115832.403605
# 4        115832.403605   77825.276898   95296.689182      115832.403605
# ...                ...            ...            ...                ...
# 165285   115832.403605   77825.276898   95296.689182      115832.403605
# 165286   115832.403605   77825.276898   95296.689182      115832.403605
# 165287   115832.403605   77825.276898   95296.689182      115832.403605
# 165288   115832.403605   77825.276898   95296.689182      115832.403605
# 165289   115832.403605   77825.276898   95296.689182      115832.403605
#
#         header.payPeriod  salary.salaries  \
# 0                    NaN           2483.0
# ...

# %%
differences
# Out:
#         header.payHigh  header.payLow  header.payMed  header.salaryHigh  \
# 0        113349.403605   75342.276898   92813.689182      113349.403605
# 1        113348.403605   75341.276898   92812.689182      113348.403605
# 2        113347.403605   75340.276898   92811.689182      113347.403605
# 3        113346.403605   75339.276898   92810.689182      113346.403605
# 4        113345.403605   75338.276898   92809.689182      113345.403605
# ...                ...            ...            ...                ...
# 165285    63757.403605   25750.276898   43221.689182       63757.403605
# 165286    63756.403605   25749.276898   43220.689182       63756.403605
# 165287    63755.403605   25748.276898   43219.689182       63755.403605
# 165288    63754.403605   25747.276898   43218.689182       63754.403605
# 165289    63753.403605   25746.276898   43217.689182       63753.403605
#
#         header.payPeriod  salary.salaries  \
# 0                    NaN              0.0
# ...

# %%
df_selec7['salary.country.currency.currencyCode'].unique()
# Out:
# array([nan, 'GBP'], dtype=object)

# %% [markdown]
# ### __Creamos una funcion para ver si podemos complementar datos de otras columnas__

# %%
#busca comparar el valor de una columna específica en dos dataframes distintos y determinar si sería útil combinarlos usando el método combine_first().
#La idea detrás de este proceso es que en algunos casos, puede haber datos faltantes en un dataframe que se puedan completar con información de otro dataframe.


def compare_cols(df1, df2, col1, col2):
    if col1 not in df1.columns:
        print(f"La columna {col1} no se encuentra en el primer dataframe.")
    elif col2 not in df2.columns:
        print(f"La columna {col2} no se encuentra en el segundo dataframe.")
    elif df1[col1].isnull().all() or df2[col2].isnull().all():
        print("Uno de los dataframes no tiene valores en la columna especificada.")
    elif df1.index.equals(df2.index):
        nulls1 = df1[col1].isnull().sum()
        nulls2 = df2[col2].isnull().sum()
        if nulls1 > 0 and nulls2 == 0:
            print("Este dataframe puede ser utilizado para combinar con el otro usando .combine_first().")
        elif nulls2 > 0 and nulls1 == 0:
            print("El otro dataframe puede ser utilizado para combinar con este usando .combine_first().")
        else:
            print("Ambos dataframes tienen valores en la columna especificada.")
    else:
        print("Los dataframes tienen índices diferentes.")

# %%
compare_cols(df_selec7, df_selec7, 'salary.country.currency.currencyCode', 'salary.country.currencyCode')
# Out:
# Ambos dataframes tienen valores en la columna especificada.

# %%
compare_cols(df_selec7, df_selec8, 'salary.country.currency.currencyCode', 'salary.currency.currencyCode')
# Out:
# Ambos dataframes tienen valores en la columna especificada.

# %%
compare_cols(df_selec7, df_selec7, 'salary.country.currency.currencyCode', "salary.country.currency.displayName")
# Out:
# Ambos dataframes tienen valores en la columna especificada.

# %%
compare_cols(df_selec7, df_selec7, 'salary.country.currency.currencyCode', "salary.country.currency.name")
# Out:
# Ambos dataframes tienen valores en la columna especificada.

# %% [markdown]
# ### __Creacion de la parte economica del dataframe__

# %%
#Concatenamos todas las filas que necesitamos
df_pa = df_use[["salary.salaries"]]
df_pb = differences[["header.payHigh", "header.payLow",	"header.payMed", "header.salaryHigh"]]
df_pc = df_selec4[["header.payPeriod"]]
df_d = df_selec7['salary.country.currency.currencyCode']


df_economy = pd.concat([df_pa, df_pb, df_pc, df_d], axis=1)

# %%
df_economy.sample(6)
# Out:
#         salary.salaries  header.payHigh  header.payLow  header.payMed  \
# 94749           25553.0    90279.403605   52272.276898   69743.689182
# 30368           73575.0    42257.403605    4250.276898   21721.689182
# 94088           32811.0    83021.403605   45014.276898   62485.689182
# 163450          31522.0    84310.403605   46303.276898   63774.689182
# 37337             478.0   115354.403605   77347.276898   94818.689182
# 43222           74849.0    40983.403605    2976.276898   20447.689182
#
#         header.salaryHigh header.payPeriod  \
# 94749        90279.403605              NaN
# 30368        42257.403605              NaN
# 94088        83021.403605              NaN
# 163450       84310.403605              NaN
# 37337       115354.403605              NaN
# 43222        40983.403605              NaN
#
#        salary.country.currency.currencyCode
# 94749                                   GBP
# 30368                                   NaN
# ...
