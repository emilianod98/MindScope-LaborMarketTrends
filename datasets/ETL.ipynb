# %%
import pandas as pd

# %%
df = pd.read_csv('./csv/glassdoor.csv')
df
# Out:
#         benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 0                            0.000000             2801.0               2801.0
# 1                            4.000000             2802.0               2802.0
# 2                            0.000000             2803.0               2803.0
# 3                            0.000000             2804.0               2804.0
# 4                            0.000000             2805.0               2805.0
# ...                               ...                ...                  ...
# 165285                       0.000000            58396.0              58396.0
# 165286                       3.941176            58397.0              58397.0
# 165287                       0.000000            58398.0              58398.0
# 165288                       0.000000            58399.0              58399.0
# 165289                       0.000000            58400.0              58400.0
#
# ...

# %%
df1 = df.iloc[:, :20]  
df2 = df.iloc[:, 21:40]  
df3 = df.iloc[:, 41:60]  
df4 = df.iloc[:, 61:80] 
df5 = df.iloc[:, 81:100] 
df6 = df.iloc[:, 101:120] 
df7 = df.iloc[:, 121:140] 
df8 = df.iloc[:, 141:]

# %%
# Verificar los conjuntos de datos resultantes
df1.head()
# Out:
#    benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 0                            0.0             2801.0               2801.0
# 1                            4.0             2802.0               2802.0
# 2                            0.0             2803.0               2803.0
# 3                            0.0             2804.0               2804.0
# 4                            0.0             2805.0               2805.0
#
#    benefits.numRatings benefits.employerSummary  breadCrumbs  \
# 0                    0                      NaN         2801
# 1                    3                      NaN         2802
# 2                    0                      NaN         2803
# 3                    0                      NaN         2804
# 4                    0                      NaN         2805
#
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName  \
# 0                      -1              2183810            Modus Group
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   benefits.benefitRatingDecimal       165290 non-null  float64
#  1   benefits.comments                   165289 non-null  float64
#  2   benefits.highlights                 165289 non-null  float64
#  3   benefits.numRatings                 165290 non-null  int64
#  4   benefits.employerSummary            5749 non-null    object
#  5   breadCrumbs                         165290 non-null  int64
#  6   gaTrackerData.category              165290 non-null  int64
#  7   gaTrackerData.empId                 165290 non-null  int64
#  8   gaTrackerData.empName               147081 non-null  object
#  9   gaTrackerData.empSize               147081 non-null  object
#  10  gaTrackerData.expired               165290 non-null  bool
# ...

# %%
#df['benefits.benefitRatingDecimal'].unique() 
df['benefits.comments'].unique()
#df['benefits.highlights'].unique()
#df['benefits.numRatings'].unique()
#df['benefits.employerSummary'].unique()
#df['breadCrumbs'].unique()
#df['gaTrackerData.category'].unique()
#df['gaTrackerData.empId'].unique()
#df['gaTrackerData.empName'].unique()
#df['gaTrackerData.empSize'].unique()
#df['gaTrackerData.expired'].unique()
#df['gaTrackerData.industry'].unique()
#df['gaTrackerData.industryId'].unique()
#df['gaTrackerData.jobId.long'].unique()
#df['gaTrackerData.jobId.int'].unique()
#df['gaTrackerData.jobTitle'].unique()
#df['gaTrackerData.location'].unique()
#df['gaTrackerData.locationId'].unique()
#df['gaTrackerData.locationType'].unique()
#df['gaTrackerData.pageRequestGuid.guid'].unique()
# Out:
# array([ 2801.,  2802.,  2803., ..., 58398., 58399., 58400.])

# %%
df2.head()
# Out:
#    gaTrackerData.pageRequestGuid.part1  gaTrackerData.pageRequestGuid.part2  \
# 0                        1573414548978                 -5662085852901386834
# 1                        1573414548943                 -6802041636413660434
# 2                        1573414548933                 -8126337365693101690
# 3                        1573414548924                 -6813034024377827176
# 4                        1573414548922                 -7319388449201166980
#
#         gaTrackerData.sector  gaTrackerData.sectorId  \
# 0                    Finance                   10010
# 1  Biotech & Pharmaceuticals                   10005
# 2                        NaN                       0
# 3                        NaN                       0
# 4          Business Services                   10006
#
#   gaTrackerData.profileConversionTrackingParams.trackingCAT  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Data columns (total 19 columns):
#  #   Column                                                        Non-Null Count   Dtype
# ---  ------                                                        --------------   -----
#  0   gaTrackerData.pageRequestGuid.part1                           165290 non-null  int64
#  1   gaTrackerData.pageRequestGuid.part2                           165290 non-null  int64
#  2   gaTrackerData.sector                                          117917 non-null  object
#  3   gaTrackerData.sectorId                                        165290 non-null  int64
#  4   gaTrackerData.profileConversionTrackingParams.trackingCAT     17657 non-null   object
#  5   gaTrackerData.profileConversionTrackingParams.trackingSRC     17657 non-null   float64
#  6   gaTrackerData.profileConversionTrackingParams.trackingXSP     35122 non-null   float64
# ...

# %%
df['gaTrackerData.pageRequestGuid.part1'].unique()
df['gaTrackerData.pageRequestGuid.part2'].unique()
df['gaTrackerData.sector'].unique()
df['gaTrackerData.sectorId'].unique()
df['gaTrackerData.profileConversionTrackingParams.trackingCAT'].unique()
df['gaTrackerData.profileConversionTrackingParams.trackingSRC'].unique()
df['gaTrackerData.profileConversionTrackingParams.trackingXSP'].unique()
df['gaTrackerData.jobViewTrackingResult.jobViewDisplayTimeMillis'].unique()
df['gaTrackerData.jobViewTrackingResult.requiresTracking'].unique()
df['gaTrackerData.jobViewTrackingResult.trackingUrl'].unique()
df['header.adOrderId'].unique()
df['header.advertiserType'].unique()
df['header.applicationId'].unique()
df['header.applyButtonDisabled'].unique()
df['header.applyUrl'].unique()
df['header.blur'].unique()
df['header.coverPhoto'].unique()
df['header.easyApply'].unique()
df['header.employerId'].unique()
# Out:
# array([-5662085852901386834, -6802041636413660434, -8126337365693101690,
#        ..., -5421722178620676083, -7286354170547136909,
#        -6772078686494605673], dtype=int64)

# %%
df3.head()
# Out:
#    header.expired  header.gocId  header.hideCEOInfo  \
# 0           False            -1               False
# 1           False            -1               False
# 2           False            -1               False
# 3           False            -1               False
# 4           False            -1               False
#
#                                      header.jobTitle  header.locId  \
# 0                 Biogas Project Development Manager       3094484
# 1  Quality Manager - Boehringer Ingelheim Healthc...       3183562
# 2     Senior Software Engineer (PHP, Elixir, Python)       2802090
# 3                                Senior SQA Engineer       3212296
# 4                                   Research Manager       2940587
#
#   header.location header.locationType  \
# 0          Warsaw                   C
# 1           Porto                   C
# 2           Milan                   C
# 3         Karāchi                   C
# 4       Bengaluru                   C
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   header.expired       165290 non-null  bool
#  1   header.gocId         165290 non-null  int64
#  2   header.hideCEOInfo   165290 non-null  bool
#  3   header.jobTitle      165290 non-null  object
#  4   header.locId         165290 non-null  int64
#  5   header.location      165285 non-null  object
#  6   header.locationType  165267 non-null  object
#  7   header.logo          133070 non-null  object
#  8   header.logo2x        133070 non-null  object
#  9   header.organic       165290 non-null  bool
#  10  header.overviewUrl   165290 non-null  object
#  11  header.posted        165290 non-null  object
#  12  header.rating        165290 non-null  float64
#  13  header.saved         165290 non-null  bool
#  14  header.savedJobId    165290 non-null  int64
# ...

# %%
df['header.expired'].unique()
df['header.gocId'].unique()
df['header.hideCEOInfo'].unique()
df['header.jobTitle'].unique()
df['header.locId'].unique()
df['header.location'].unique()
df['header.locationType'].unique()
df['header.logo'].unique()
df['header.logo2x'].unique()
df['header.organic'].unique()
df['header.overviewUrl'].unique()
df['header.posted'].unique()
df['header.rating'].unique()
df['header.saved'].unique()
df['header.savedJobId'].unique()
df['header.sgocId'].unique()
df['header.sponsored'].unique()
df['header.userAdmin'].unique()
df['header.uxApplyType'].unique()

# %%
df4.head()
# Out:
#   header.normalizedJobTitle header.urgencyLabel header.urgencyLabelForMessage  \
# 0                       NaN                 NaN                           NaN
# 1                       NaN                 NaN                           NaN
# 2                       NaN                 NaN                           NaN
# 3                       NaN                 NaN                           NaN
# 4                       NaN                 NaN                           NaN
#
#   header.urgencyMessage header.needsCommission  header.payHigh  header.payLow  \
# 0                   NaN                    NaN             NaN            NaN
# 1                   NaN                    NaN             NaN            NaN
# 2                   NaN                    NaN             NaN            NaN
# 3                   NaN                    NaN             NaN            NaN
# 4                   NaN                    NaN             NaN            NaN
#
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   header.normalizedJobTitle      29155 non-null   object
#  1   header.urgencyLabel            4521 non-null    object
#  2   header.urgencyLabelForMessage  4521 non-null    object
#  3   header.urgencyMessage          4521 non-null    object
#  4   header.needsCommission         3662 non-null    object
#  5   header.payHigh                 3662 non-null    float64
#  6   header.payLow                  3662 non-null    float64
#  7   header.payMed                  3642 non-null    float64
#  8   header.payPeriod               3637 non-null    object
#  9   header.salaryHigh              3662 non-null    float64
#  10  header.salaryLow               3662 non-null    float64
#  11  header.salarySource            3662 non-null    object
# ...

# %%
df['header.normalizedJobTitle'].unique()
df['header.urgencyLabel'].unique()
df['header.urgencyLabelForMessage'].unique()
df['header.urgencyMessage'].unique()
df['header.needsCommission'].unique()
df['header.payHigh'].unique()
df['header.payLow'].unique()
df['header.payMed'].unique()
df['header.payPeriod'].unique()
df['header.salaryHigh'].unique()
df['header.salaryLow'].unique()
df['header.salarySource'].unique()
df['job.description'].unique()
df['job.discoverDate'].unique()
df['job.eolHashCode'].unique()
df['job.importConfigId'].unique()
df['job.jobReqId.long'].unique()
df['job.jobReqId.int'].unique()
df['job.jobSource'].unique()

# %%
df5.head()
# Out:
#    job.listingId.long  job.listingId.int map.country       map.employerName  \
# 0        3.227100e+09                NaN      Poland            Modus Group
# 1        3.406582e+09                NaN         NaN   Boehringer Ingelheim
# 2        3.230738e+09                NaN       Italy        Immobiliare.it
# 3        3.406677e+09                NaN          PK                  Codup
# 4        3.201516e+09                NaN          IN  Markelytics Solutions
#
#    map.lat  map.lng map.location map.address map.postalCode  \
# 0  52.2500  21.0000       Warsaw         NaN            NaN
# 1  41.1500  -8.6167        Porto         NaN            NaN
# 2  45.4667   9.2000        Milan         NaN            NaN
# 3  24.8667  67.0500      Karāchi         NaN            NaN
# 4  12.9670  77.5873    Bengaluru         NaN            NaN
#
#                             overview.allBenefitsLink  \
# 0  /Benefits/Modus-Group-UK-Benefits-EI_IE2183810...
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   job.listingId.long        165044 non-null  float64
#  1   job.listingId.int         246 non-null     float64
#  2   map.country               115262 non-null  object
#  3   map.employerName          147149 non-null  object
#  4   map.lat                   165290 non-null  float64
#  5   map.lng                   165290 non-null  float64
#  6   map.location              165285 non-null  object
#  7   map.address               14182 non-null   object
#  8   map.postalCode            13973 non-null   object
#  9   overview.allBenefitsLink  147081 non-null  object
#  10  overview.allPhotosLink    147081 non-null  object
#  11  overview.allReviewsLink   147081 non-null  object
#  12  overview.allSalariesLink  147081 non-null  object
# ...

# %%
df['job.listingId.long'].unique()
df['job.listingId.int'].unique()
df['map.country'].unique()
df['map.employerName'].unique()
df['map.lat'].unique()
df['map.lng'].unique()
df['map.location'].unique()
df['map.address'].unique()
df['map.postalCode'].unique()
df['overview.allBenefitsLink'].unique()
df['overview.allPhotosLink'].unique()
df['overview.allReviewsLink'].unique()
df['overview.allSalariesLink'].unique()
df['overview.foundedYear'].unique()
df['overview.hq'].unique()
df['overview.industry'].unique()
df['overview.industryId'].unique()
df['overview.revenue'].unique()
df['overview.sector'].unique()

# %%
df6.head()
# Out:
#            overview.size overview.stock      overview.type  \
# 0  501 to 1000 employees            NaN  Company - Private
# 1       10000+ employees            NaN  Company - Private
# 2   201 to 500 employees            NaN  Company - Private
# 3      1 to 50 employees            NaN  Company - Private
# 4   201 to 500 employees            NaN  Company - Private
#
#                                 overview.description overview.mission  \
# 0  We are the drivers of the future who offer a g...              NaN
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4                                                NaN              NaN
#
#                overview.website overview.allVideosLink  overview.competitors  \
# 0               www.modus.group                    NaN                   NaN
# ...

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   overview.size                147081 non-null  object
#  1   overview.stock               46357 non-null   object
#  2   overview.type                147081 non-null  object
#  3   overview.description         86959 non-null   object
#  4   overview.mission             52156 non-null   object
#  5   overview.website             100184 non-null  object
#  6   overview.allVideosLink       32841 non-null   object
#  7   overview.competitors         47988 non-null   float64
#  8   overview.companyVideo        26420 non-null   object
#  9   photos                       101429 non-null  float64
#  10  rating.ceo.name              112334 non-null  object
#  11  rating.ceo.photo             79576 non-null   object
# ...

# %%
df['overview.size'].unique()
df['overview.stock'].unique()
df['overview.type'].unique()
df['map.employerName'].unique()
df['overview.description'].unique()
df['overview.mission'].unique()
df['overview.allVideosLink'].unique()
df['overview.competitors'].unique()
df['overview.companyVideo'].unique()
df['photos'].unique()
df['rating.ceo.name'].unique()
df['rating.ceo.photo'].unique()
df['rating.ceo.photo2x'].unique()
df['rating.ceo.ratingsCount'].unique()
df['rating.ceoApproval'].unique()
df['rating.recommendToFriend'].unique()
df['rating.starRating'].unique()
df['reviews'].unique()
df['salary.country.cc3LetterISO'].unique()

# %%
df7.head()
# Out:
#   salary.country.continent.continentCode  \
# 0                                    NaN
# 1                                     EU
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#   salary.country.continent.continentName  salary.country.continent.id  \
# 0                                    NaN                          NaN
# 1                                 Europe                          4.0
# 2                                    NaN                          NaN
# 3                                    NaN                          NaN
# 4                                    NaN                          NaN
#
#   salary.country.continent.new salary.country.countryFIPS  \
# 0                          NaN                        NaN
# 1                        False                         UK
# 2                          NaN                        NaN
# ...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Data columns (total 19 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   salary.country.continent.continentCode         76777 non-null  object
#  1   salary.country.continent.continentName         76777 non-null  object
#  2   salary.country.continent.id                    76777 non-null  float64
#  3   salary.country.continent.new                   76777 non-null  object
#  4   salary.country.countryFIPS                     76777 non-null  object
#  5   salary.country.currency.currencyCode           76777 non-null  object
#  6   salary.country.currency.defaultFractionDigits  76777 non-null  float64
#  7   salary.country.currency.displayName            76777 non-null  object
#  8   salary.country.currency.id                     76777 non-null  float64
# ...

# %%
df['salary.country.continent.continentCode'].unique()
df['salary.country.continent.continentName'].unique()
df['salary.country.continent.id'].unique()
df['salary.country.continent.new'].unique()
df['salary.country.countryFIPS'].unique()
df['salary.country.currency.currencyCode'].unique()
df['salary.country.currency.defaultFractionDigits'].unique()
df['salary.country.currency.displayName'].unique()
df['salary.country.currency.id'].unique()
df['salary.country.currency.name'].unique()
df['salary.country.currency.negativeTemplate'].unique()
df['salary.country.currency.new'].unique()
df['salary.country.currency.positiveTemplate'].unique()
df['salary.country.currency.symbol'].unique()
df['salary.country.currencyCode'].unique()
df['salary.country.defaultLocale'].unique()
df['salary.country.defaultName'].unique()
df['salary.country.defaultShortName'].unique()
df['salary.country.employerSolutionsCountry'].unique()

# %%
df8.head()
# Out:
#   salary.country.longName salary.country.major salary.country.name  \
# 0                     NaN                  NaN                 NaN
# 1          United Kingdom                 True      United Kingdom
# 2                     NaN                  NaN                 NaN
# 3                     NaN                  NaN                 NaN
# 4                     NaN                  NaN                 NaN
#
#   salary.country.new  salary.country.population salary.country.shortName  \
# 0                NaN                        NaN                      NaN
# 1              False                 60363602.0                       UK
# 2                NaN                        NaN                      NaN
# 3                NaN                        NaN                      NaN
# 4                NaN                        NaN                      NaN
#
#   salary.country.tld salary.country.type salary.country.uniqueName  \
# ...

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165290 entries, 0 to 165289
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   salary.country.longName                76777 non-null   object
#  1   salary.country.major                   76777 non-null   object
#  2   salary.country.name                    76777 non-null   object
#  3   salary.country.new                     76777 non-null   object
#  4   salary.country.population              76777 non-null   float64
#  5   salary.country.shortName               76777 non-null   object
#  6   salary.country.tld                     76777 non-null   object
#  7   salary.country.type                    76777 non-null   object
#  8   salary.country.uniqueName              76777 non-null   object
#  9   salary.country.usaCentricDisplayName   76777 non-null   object
# ...

# %%
df['salary.country.longName'].unique()
df['salary.country.major'].unique()
df['salary.country.name'].unique()
df['salary.country.new'].unique()
df['salary.country.population'].unique()
df['salary.country.shortName'].unique()
df['salary.country.tld'].unique()
df['salary.country.type'].unique()
df['salary.country.uniqueName'].unique()
df['salary.country.usaCentricDisplayName'].unique()
df['alary.currency.currencyCode'].unique()
df['salary.currency.defaultFractionDigits'].unique()
df['salary.currency.displayName'].unique()
df['salary.currency.id'].unique()
df['salary.currency.name'].unique()
df['salary.currency.negativeTemplate'].unique()
df['salary.currency.new'].unique()
df['salary.currency.positiveTemplate'].unique()
df['salary.currency.symbol'].unique()
df['salary.lastSalaryDate'].unique()
df['salary.salaries'].unique()
df['wwfu'].unique()
